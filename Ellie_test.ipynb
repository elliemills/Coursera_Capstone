# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     ca-certificates-2019.9.11  |       hecc5488_0         144 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     openssl-1.1.1c             |       h516909a_0         2.1 MB  conda-forge
#     certifi-2019.9.11          |           py36_0         147 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.20.0-py_0       conda-forge
#
# ...

# %%
Torontodemographics_df = pd.read_html("https://en.wikipedia.org/wiki/Demographics_of_Toronto_neighbourhoods")[0]

# %%
Torontodemographics_df.head(10)
# Out:
#     0                                                  1
# 0 NaN  This article's factual accuracy may be comprom...

# %%
postalcodes_df = pd.read_html("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")[0]

# %%
postalcodes_df.head(10)
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M5A  Downtown Toronto       Regent Park
# 6      M6A        North York  Lawrence Heights
# 7      M6A        North York    Lawrence Manor
# 8      M7A      Queen's Park      Not assigned
# 9      M8A      Not assigned      Not assigned

# %%
conda install -c anaconda beautifulsoup4
# Out:
#   File "<ipython-input-9-16f5079f01d1>", line 1
#     conda install -c anaconda beautifulsoup4
#                 ^
# SyntaxError: invalid syntax

# %%
# !pip install requests

# !pip install beautifulsoup4

# %%
c_url = requests.get('https://en.wikipedia.org/wiki/Demographics_of_Toronto_neighbourhoods').text

from bs4 import BeautifulSoup

soup = BeautifulSoup(c_url,'lxml')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Demographics of Toronto neighbourhoods - Wikipedia
#   </title>
#   <script>
# ...

# %%
tb = soup.find('table', class_='wikitable')

# %%
for link in tb.find_all('b'):
    name = link.find('a')
    print(name)
# Out:
# <a class="mw-redirect" href="/wiki/Census_metropolitan_area" title="Census metropolitan area">CMA</a>
# None
# None
# None
# None
# None
# None
# None

# %%
# Specify with which URL/web page we are going to be scraping
url = requests.get('https://en.wikipedia.org/wiki/List_of_Asian_countries_by_area').text

# %%
# import the BeautifulSoup library so we can parse HTML and XML documents
from bs4 import BeautifulSoup

#Parse the HTML from our URL into the BeautifulSoup parse tree format
soup = BeautifulSoup(url, "lxml")

# %%
#To look at the HTML underlying to the web 
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of Asian countries by area - Wikipedia
#   </title>
#   <script>
# ...

# %%
#To get the title of the page
soup.title()
# Out:
# []

# %%
# use the 'find_all' function to bring back all instances of the 'table' tag in the HTML and store in 'all_tables' variable
all_tables=soup.find_all("table")
all_tables
# Out:
# [<table class="box-More_citations_needed plainlinks metadata ambox ambox-content ambox-Refimprove" role="presentation"><tbody><tr><td class="mbox-image"><div style="width:52px"><a class="image" href="/wiki/File:Question_book-new.svg"><img alt="" data-file-height="399" data-file-width="512" decoding="async" height="39" src="//upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/50px-Question_book-new.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/75px-Question_book-new.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/100px-Question_book-new.svg.png 2x" width="50"/></a></div></td><td class="mbox-text"><div class="mbox-text-span">This article <b>needs additional citations for <a href="/wiki/Wikipedia:Verifiability" title="Wikipedia:Verifiability">verification</a></b>.<span class="hide-when-compact"> Please help <a class="external text" href="https://en.wikipedia.org/w/index.php?title=List_of_Asian_cou
# ...

# %%
# use the 'find_all' function to bring back all instances of the 'table' tag in the HTML and store in 'all_tables' variable
My_table = soup.find('table',{'class':'wikitable sortable'})
My_table
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Rank
# </th>
# <th>Country
# </th>
# <th>Area (km²)
# </th>
# <th class="unsortable">Notes
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><span class="flagicon" style="display:inline-block;width:25px;"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/f/f3/Flag_of_Russia.svg/23px-Flag_of_Russia.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/f/f3/Flag_of_Russia.svg/35px-Flag_of_Russia.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/f/f3/Flag_of_Russia.svg/45px-Flag_of_Russia.svg.png 2x" width="23"/></span> <a href="/wiki/Russia" title="Russia">Russia</a>*
# </td>
# <td>13,100,000
# </td>
# <td>17,098,242 including European part<sup class="reference" id="cite_ref-russiaTotalAreaByCIA_1-0"><a href="#cite_note-russiaTotalAreaByCIA-1">[1]</a></sup>
# </td></tr>
# <tr>
# <td>2
# </td>
# ...

# %%
links = My_table.findAll('a')
links
# Out:
# [<a href="/wiki/Russia" title="Russia">Russia</a>,
#  <a href="#cite_note-russiaTotalAreaByCIA-1">[1]</a>,
#  <a href="/wiki/China" title="China">China</a>,
#  <a href="/wiki/Hong_Kong" title="Hong Kong">Hong Kong</a>,
#  <a href="/wiki/Macau" title="Macau">Macau</a>,
#  <a href="/wiki/India" title="India">India</a>,
#  <a href="#cite_note-2">[2]</a>,
#  <a href="/wiki/Kazakhstan" title="Kazakhstan">Kazakhstan</a>,
#  <a href="/wiki/Saudi_Arabia" title="Saudi Arabia">Saudi Arabia</a>,
#  <a href="/wiki/Iran" title="Iran">Iran</a>,
#  <a href="/wiki/Mongolia" title="Mongolia">Mongolia</a>,
#  <a href="/wiki/Indonesia" title="Indonesia">Indonesia</a>,
#  <a href="/wiki/Pakistan" title="Pakistan">Pakistan</a>,
#  <a href="/wiki/Turkey" title="Turkey">Turkey</a>,
#  <a href="/wiki/Myanmar" title="Myanmar">Myanmar</a>,
#  <a href="/wiki/Afghanistan" title="Afghanistan">Afghanistan</a>,
#  <a href="/wiki/Yemen" title="Yemen">Yemen</a>,
# ...

# %%
Countries = []
for link in links:
    Countries.append(link.get('title'))
    
print(Countries)
# Out:
# ['Russia', None, 'China', 'Hong Kong', 'Macau', 'India', None, 'Kazakhstan', 'Saudi Arabia', 'Iran', 'Mongolia', 'Indonesia', 'Pakistan', 'Turkey', 'Myanmar', 'Afghanistan', 'Yemen', 'Thailand', 'Turkmenistan', 'Uzbekistan', 'Iraq', 'Japan', 'Vietnam', 'Malaysia', 'Oman', 'Philippines', 'Laos', 'Kyrgyzstan', 'Syria', 'Golan Heights', 'Cambodia', 'Bangladesh', 'Nepal', 'Tajikistan', 'North Korea', 'South Korea', 'Jordan', 'Azerbaijan', 'United Arab Emirates', 'Georgia (country)', 'Sri Lanka', 'Egypt', 'Bhutan', 'Taiwan', 'Armenia', 'Kuwait', 'East Timor', 'Qatar', 'Lebanon', 'State of Palestine', 'Brunei', 'Singapore', 'Bahrain', 'Maldives']

# %%
import pandas as pd
df = pd.DataFrame()
df['Country'] = Countries

df
# Out:
#                  Country
# 0                 Russia
# 1                   None
# 2                  China
# 3              Hong Kong
# 4                  Macau
# 5                  India
# 6                   None
# 7             Kazakhstan
# 8           Saudi Arabia
# 9                   Iran
# 10              Mongolia
# 11             Indonesia
# 12              Pakistan
# 13                Turkey
# 14               Myanmar
# 15           Afghanistan
# 16                 Yemen
# 17              Thailand
# 18          Turkmenistan
# 19            Uzbekistan
# 20                  Iraq
# 21                 Japan
# 22               Vietnam
# 23              Malaysia
# 24                  Oman
# 25           Philippines
# 26                  Laos
# 27            Kyrgyzstan
# 28                 Syria
# 29         Golan Heights
# 30              Cambodia
# 31            Bangladesh
# 32                 Nepal
# 33            Tajikistan
# 34           North Korea
# 35           South Korea
# ...

# %%
c_url = requests.get('https://en.wikipedia.org/wiki/Demographics_of_Toronto_neighbourhoods').text

from bs4 import BeautifulSoup

soup = BeautifulSoup(c_url,'lxml')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Demographics of Toronto neighbourhoods - Wikipedia
#   </title>
#   <script>
# ...

# %%
# use the 'find_all' function to bring back all instances of the 'table' tag in the HTML and store in 'all_tables' variable
all_tables=soup.find_all("table")
all_tables
# Out:
# [<table class="box-Update plainlinks metadata ambox ambox-content ambox-Update" role="presentation"><tbody><tr><td class="mbox-image"><div style="width:52px"><img alt="Ambox current red.svg" data-file-height="290" data-file-width="360" decoding="async" height="34" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/98/Ambox_current_red.svg/42px-Ambox_current_red.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/98/Ambox_current_red.svg/63px-Ambox_current_red.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/98/Ambox_current_red.svg/84px-Ambox_current_red.svg.png 2x" width="42"/></div></td><td class="mbox-text"><div class="mbox-text-span">This article's <b><a href="/wiki/Wikipedia:Accuracy_dispute" title="Wikipedia:Accuracy dispute">factual accuracy</a> may be compromised due to out-of-date information</b>.<span class="hide-when-compact"> Please update this article to reflect recent events or newly available information.</span> <small class="date-contain
# ...

# %%
# use the 'find_all' function to bring back all instances of the 'table' tag in the HTML and store in 'all_tables' variable
My_table = soup.find('table',{'class':'wikitable sortable'})
#first row is empty
tableRows = [[td.text for td in row.find_all("td")] for row in My_table.find_all("tr")[1:]]
print(tableRows)
# Out:
# [['Toronto CMA Average\n', '\n', 'All\n', '5,113,149\n', '5903.63\n', '866\n', '9.0\n', '40,704\n', '10.6\n', '11.4\n', '\n', '\n', '\n'], ['Agincourt\n', 'S\n', '0377.01, 0377.02, 0377.03, 0377.04, 0378.02, 0378.08, 0378.14, 0378.23, 0378.24\n', '44,577\n', '12.45\n', '3580\n', '4.6\n', '25,750\n', '11.1\n', '5.9\n', 'Cantonese (19.3%)\n', '19.3% Cantonese\n', '\n'], ['Alderwood\n', 'E\n', '0211.00, 0212.00\n', '11,656\n', '4.94\n', '2360\n', '-4.0\n', '35,239\n', '8.8\n', '8.5\n', 'Polish (6.2%)\n', '06.2% Polish\n', '\n'], ['Alexandra Park\n', 'OCoT\n', '0039.00\n', '4,355\n', '0.32\n', '13,609\n', '0.0\n', '19,687\n', '13.8\n', '28.0\n', 'Cantonese (17.9%)\n', '17.9% Cantonese\n', '\n'], ['Allenby\n', 'OCoT\n', '0140.00\n', '2,513\n', '0.58\n', '4333\n', '-1.0\n', '245,592\n', '5.2\n', '3.4\n', 'Russian (1.4%)\n', '01.4% Russian\n', '\n'], ['Amesbury\n', 'NY\n', '0280.00, 0281.01, 0281.02\n', '17,318\n', '3.51\n', '4,934\n', '1.1\n', '27,546\n', '16.4\n', '19.7\n', 'Spanish (6.1%
# ...

# %%
#get headers for dataframe
tableHeaders = [th.text for th in table.find_all("th")]

import pandas as pd

#build df from tableRows and headers
df = pd.DataFrame(tableRows, columns=tableHeaders)

print(df)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-53-df8881fe34cb> in <module>
#       5
#       6 #build df from tableRows and headers
# ----> 7 df = pd.DataFrame(tableRows, columns=tableHeaders)
#       8
#       9 print(df)
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     433                     if is_named_tuple(data[0]) and columns is None:
#     434                         columns = data[0]._fields
# --> 435                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     436                     columns = ensure_index(columns)
#     437
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/internals/construction.py in to_arrays(data, columns, coerce_float, dtype)
#     402     if isinstance(data[0], (list, tuple)):
# ...

# %%
links = My_table.findAll('a')
links
# Out:
# [<a class="mw-redirect" href="/wiki/Census_metropolitan_area" title="Census metropolitan area">CMA</a>,
#  <a href="/wiki/Agincourt,_Toronto" title="Agincourt, Toronto">Agincourt</a>,
#  <a class="image" href="/wiki/File:Agincourt_map.PNG"><img alt="Agincourt map.PNG" data-file-height="901" data-file-width="792" decoding="async" height="114" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/42/Agincourt_map.PNG/100px-Agincourt_map.PNG" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/42/Agincourt_map.PNG/150px-Agincourt_map.PNG 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/42/Agincourt_map.PNG/200px-Agincourt_map.PNG 2x" width="100"/></a>,
#  <a href="/wiki/Alderwood,_Toronto" title="Alderwood, Toronto">Alderwood</a>,
#  <a href="/wiki/Alexandra_Park,_Toronto" title="Alexandra Park, Toronto">Alexandra Park</a>,
# ...

# %%
Name = []
for link in links:
    Name.append(link.get('title'))
    
print(Name)
# Out:
# ['Census metropolitan area', 'Agincourt, Toronto', None, 'Alderwood, Toronto', 'Alexandra Park, Toronto', None, 'Allenby, Toronto', 'Amesbury, Toronto', None, 'Armour Heights', None, 'Banbury, Toronto', 'Bathurst Manor', None, 'Bay Street', 'Bayview Village', None, 'Bayview Woods – Steeles', None, 'Bedford Park, Toronto', None, 'Bendale', None, 'Birch Cliff', None, 'Bloor West Village', 'Bracondale Hill', None, 'Branson, Toronto', None, 'Bridle Path, Toronto', None, 'Brockton Village', None, 'Cabbagetown, Toronto', None, 'Caribou Park (page does not exist)', 'Carleton Village', None, 'Casa Loma (neighbourhood)', None, 'Centennial, Toronto (page does not exist)', 'Chaplin Estates', None, 'Christie Pits', 'Church and Wellesley', None, 'Clairville, Toronto', None, 'Clairlea', None, 'Cliffcrest', None, 'Cliffside, Toronto', None, 'Corktown, Toronto', None, 'Crescent Town', None, 'Cricket Club, Toronto (page does not exist)', 'Davenport, Toronto', None, 'Davisville Village', None, 'Deer P
# ...

# %%
import pandas as pd
df = pd.DataFrame()


df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# !pip install wikipedia
# Out:
# ...
#   Stored in directory: /home/dsxuser/.cache/pip/wheels/87/2a/18/4e471fd96d12114d16fe4a446d00c3b38fb9efcb744bd31f4a
# Successfully built wikipedia
# ...

# %%
Torontodemographics_df = pd.read_html("https://en.wikipedia.org/wiki/Demographics_of_Toronto_neighbourhoods")[0]

Torontodemographics_df.head()
# Out:
#     0                                                  1
# 0 NaN  This article's factual accuracy may be comprom...

# %%
CLIENT_ID = 'FC5WMF5KAA2YQG5ICBTLLB1IL3POC450QMGGHLNYZMKSUAO5' # your Foursquare ID
CLIENT_SECRET = 'I4XMIHNH0OVB5MVYBAO4BPVRRRD4DWJQKUTUBNXWOD4GUQAI' # your Foursquare Secret
VERSION = '20190920'
LIMIT = 50
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: FC5WMF5KAA2YQG5ICBTLLB1IL3POC450QMGGHLNYZMKSUAO5
# CLIENT_SECRET:I4XMIHNH0OVB5MVYBAO4BPVRRRD4DWJQKUTUBNXWOD4GUQAI

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# %%
address = 'City of London, UK'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of Central London are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates of Central London are 51.5156177, -0.0919983.

# %%
search_query = 'Yoga'
radius = 2000
print(search_query + ' .... OK!')
# Out:
# Yoga .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=FC5WMF5KAA2YQG5ICBTLLB1IL3POC450QMGGHLNYZMKSUAO5&client_secret=I4XMIHNH0OVB5MVYBAO4BPVRRRD4DWJQKUTUBNXWOD4GUQAI&ll=51.5156177,-0.0919983&v=20190920&query=Yoga&radius=2000&limit=50'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d8cc31c6f0aa2002c805ea7'},
#  'response': {'venues': [{'id': '4efc95eac2ee80dc2e652f5e',
#     'name': 'Blue Cow Yoga',
#     'location': {'address': 'Basildon House, 7 Moorgate',
#      'crossStreet': "at King's Arms Yard",
#      'lat': 51.51528559031631,
#      'lng': -0.08976422627667482,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 51.51528559031631,
#        'lng': -0.08976422627667482}],
#      'distance': 159,
#      'postalCode': 'EC2R 6AF',
#      'cc': 'GB',
#      'city': 'London',
#      'state': 'Greater London',
#      'country': 'United Kingdom',
#      'formattedAddress': ["Basildon House, 7 Moorgate (at King's Arms Yard)",
#       'London',
#       'Greater London',
#       'EC2R 6AF',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d102941735',
#       'name': 'Yoga Studio',
#       'pluralName': 'Yoga Studios',
#       'shortName': 'Yoga Studio',
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d102941735', 'name': 'Y...    False
# 1  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...    False
# 2  [{'id': '4bf58dd8d48988d131941735', 'name': 'S...    False
# 3  [{'id': '4bf58dd8d48988d102941735', 'name': 'Y...    False
# 4  [{'id': '4bf58dd8d48988d102941735', 'name': 'Y...    False
#
#                          id            location.address location.cc  \
# 0  4efc95eac2ee80dc2e652f5e  Basildon House, 7 Moorgate          GB
# 1  54a69644498e9c8f4c99f392                7-9 Moorgate          GB
# 2  590ad8e6da2e0027dd1cd29d    Kemp House, 160, City Rd          GB
# 3  58888fa4cf44511f98a80f37              1A Magdalen St          GB
# 4  4eb77e92991165b763431b46              1A Magdalen St          GB
#
#   location.city location.country location.crossStreet  location.distance  \
# 0        London   United Kingdom  at King's Arms Yard                159
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                      name            categories  \
# 0                           Blue Cow Yoga           Yoga Studio
# 1   Heartcore City Pop-Up @ Blue Cow Yoga  Gym / Fitness Center
# 2            UnitedMind Laughter Yoga Ltd      Spiritual Center
# 3      Bikram Yoga London - London Bridge           Yoga Studio
# 4                        Hot Yoga Society           Yoga Studio
# 5                       Yoga @ Sky Garden           Yoga Studio
# 6                             Chroma Yoga           Yoga Studio
# 7                             Energy Yoga           Yoga Studio
# 8                           AM Power Yoga           Yoga Studio
# 9                    More Yoga Old Street           Yoga Studio
# 10                         Pure Yoga Zone           Yoga Studio
# 11                       Prana Yoga Space           Yoga Studio
# 12                             Yoga Place           Yoga Studio
# 13                   Yoga Room Shoreditch           Yoga Studio
# ...

# %%
dataframe_filtered.name
# Out:
# 0                             Blue Cow Yoga
# 1     Heartcore City Pop-Up @ Blue Cow Yoga
# 2              UnitedMind Laughter Yoga Ltd
# 3        Bikram Yoga London - London Bridge
# 4                          Hot Yoga Society
# 5                         Yoga @ Sky Garden
# 6                               Chroma Yoga
# 7                               Energy Yoga
# 8                             AM Power Yoga
# 9                      More Yoga Old Street
# 10                           Pure Yoga Zone
# 11                         Prana Yoga Space
# 12                               Yoga Place
# 13                     Yoga Room Shoreditch
# 14                        More Yoga Aldgate
# 15                   Fitnessonfire Hot Yoga
# 16                         Tara Yoga Centre
# 17                   Stillpoint Yoga London
# 18                         Karma Yoga House
# 19    Bodywise Yoga & Natural Health Centre
# 20                 More Yoga Exmouth Market
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
address = 'Downtown Toronto, Canada'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of Downtown Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates of Downtown Toronto are 43.655115, -79.380219.

# %%
search_query = 'Yoga'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Yoga .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=FC5WMF5KAA2YQG5ICBTLLB1IL3POC450QMGGHLNYZMKSUAO5&client_secret=I4XMIHNH0OVB5MVYBAO4BPVRRRD4DWJQKUTUBNXWOD4GUQAI&ll=43.655115,-79.380219&v=20190920&query=Yoga&radius=500&limit=50'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d8cc28ac58ed7002c55a358'},
#  'response': {'venues': [{'id': '542044a3498e78ca08c471bd',
#     'name': 'Yoga Tree Bay and Dundas',
#     'location': {'address': '123 Dundas Street West',
#      'lat': 43.655560899041305,
#      'lng': -79.38447758373427,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655560899041305,
#        'lng': -79.38447758373427}],
#      'distance': 346,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['123 Dundas Street West', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d102941735',
#       'name': 'Yoga Studio',
#       'pluralName': 'Yoga Studios',
#       'shortName': 'Yoga Studio',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1569505930',
#     'hasPerk': False},
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe2 = json_normalize(venues)
dataframe2.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d102941735', 'name': 'Y...    False
# 1  [{'id': '4bf58dd8d48988d102941735', 'name': 'Y...    False
# 2  [{'id': '4bf58dd8d48988d102941735', 'name': 'Y...    False
# 3                                                 []    False
# 4  [{'id': '4bf58dd8d48988d1f1931735', 'name': 'G...    False
#
#                          id               location.address location.cc  \
# 0  542044a3498e78ca08c471bd         123 Dundas Street West          CA
# 1  50f08a5de4b03f20fe23e7e3               319 Yonge Street          CA
# 2  4d80128e86efba7a378e2e0d  100 King St. West, Suite 5600          CA
# 3  544e5ddc498e91fa4e1edb22                            NaN          CA
# 4  4fa1c359e4b065011a9da2c9                            NaN          CA
#
#   location.city location.country location.crossStreet  location.distance  \
# 0       Toronto           Canada                  NaN                346
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe2_filtered = dataframe2.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe2_filtered['categories'] = dataframe2_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe2_filtered.columns = [column.split('.')[-1] for column in dataframe2_filtered.columns]

dataframe2_filtered
# Out:
#                                    name             categories  \
# 0              Yoga Tree Bay and Dundas            Yoga Studio
# 1  Extreme Fitness Yoga/Hot Yoga Studio            Yoga Studio
# 2                           Yoga Studio            Yoga Studio
# 3                             Yoga Tree                   None
# 4          Yoga Studio 155 Dalhousie St  General Entertainment
# 5                 Float Suspension Yoga            Yoga Studio
# 6                 Yogatree Bay & Dundas            Yoga Studio
# 7                              Yogatree                   None
#
#                          address  cc     city country      crossStreet  \
# 0         123 Dundas Street West  CA  Toronto  Canada              NaN
# 1               319 Yonge Street  CA  Toronto  Canada              NaN
# 2  100 King St. West, Suite 5600  CA  Toronto  Canada          Bay St.
# 3                            NaN  CA      NaN  Canada              NaN
# ...

# %%
dataframe2_filtered.name
# Out:
# 0                Yoga Tree Bay and Dundas
# 1    Extreme Fitness Yoga/Hot Yoga Studio
# 2                             Yoga Studio
# 3                               Yoga Tree
# 4            Yoga Studio 155 Dalhousie St
# 5                   Float Suspension Yoga
# 6                   Yogatree Bay & Dundas
# 7                                Yogatree
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe2_filtered.lat, dataframe2_filtered.lng, dataframe2_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
address = 'Midtown Manhatten, US'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of Midtown Manhatten are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates of Midtown Manhatten are 40.7639894, -73.9945641016504.

# %%
search_query = 'Yoga'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Yoga .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=FC5WMF5KAA2YQG5ICBTLLB1IL3POC450QMGGHLNYZMKSUAO5&client_secret=I4XMIHNH0OVB5MVYBAO4BPVRRRD4DWJQKUTUBNXWOD4GUQAI&ll=40.7639894,-73.9945641016504&v=20190920&query=Yoga&radius=500&limit=50'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d8cc2b74928226c3950567e'},
#  'response': {'venues': [{'id': '5a3f05258c812a1adab02da9',
#     'name': 'Yamaka Yoga',
#     'location': {'address': '540 W 49th St',
#      'lat': 40.764662,
#      'lng': -73.994225,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.764662,
#        'lng': -73.994225}],
#      'distance': 80,
#      'postalCode': '10019',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['540 W 49th St',
#       'New York, NY 10019',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d102941735',
#       'name': 'Yoga Studio',
#       'pluralName': 'Yoga Studios',
#       'shortName': 'Yoga Studio',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1569505975',
#     'hasPerk': False},
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe3 = json_normalize(venues)
dataframe3.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d102941735', 'name': 'Y...    False
# 1  [{'id': '4f4528bc4b90abdf24c9de85', 'name': 'A...    False
# 2  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...    False
#
#                          id location.address location.cc location.city  \
# 0  5a3f05258c812a1adab02da9    540 W 49th St          US      New York
# 1  513f6770e4b02bc64e2d7684    600 W 42nd St          US      New York
# 2  4d4c84bd00d28cfa364fc674    Broome Street          US      New York
#
#   location.country location.crossStreet  location.distance  \
# 0    United States                  NaN                 80
# 1    United States                  NaN                498
# 2    United States               Crosby                519
#
#                            location.formattedAddress  \
# 0  [540 W 49th St, New York, NY 10019, United Sta...
# 1  [600 W 42nd St, New York, NY 10036, United Sta...
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe3_filtered = dataframe3.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe3_filtered['categories'] = dataframe3_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe3_filtered.columns = [column.split('.')[-1] for column in dataframe3_filtered.columns]

dataframe3_filtered
# Out:
#                      name            categories        address  cc      city  \
# 0             Yamaka Yoga           Yoga Studio  540 W 49th St  US  New York
# 1       Yoga Booty Ballet    Athletics & Sports  600 W 42nd St  US  New York
# 2  Ashtanga Yoga New York  Gym / Fitness Center  Broome Street  US  New York
#
#          country crossStreet  distance  \
# 0  United States         NaN        80
# 1  United States         NaN       498
# 2  United States      Crosby       519
#
#                                     formattedAddress  \
# 0  [540 W 49th St, New York, NY 10019, United Sta...
# 1  [600 W 42nd St, New York, NY 10036, United Sta...
# 2  [Broome Street (Crosby), New York, NY 10011, U...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 40.764662, 'lng':...  40.764662 -73.994225
# 1  [{'label': 'display', 'lat': 40.76118, 'lng': ...  40.761180 -73.999165
# ...

# %%
dataframe2_filtered.name
# Out:
# 0                Yoga Tree Bay and Dundas
# 1    Extreme Fitness Yoga/Hot Yoga Studio
# 2                             Yoga Studio
# 3                               Yoga Tree
# 4            Yoga Studio 155 Dalhousie St
# 5                   Float Suspension Yoga
# 6                   Yogatree Bay & Dundas
# 7                                Yogatree
# Name: name, dtype: object

# %%
Manhatten_map = folium.Map(location=[latitude, longitude], zoom_start=15)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe3_filtered.lat, dataframe3_filtered.lng, dataframe3_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(Manhatten_map)

# display map
Manhatten_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
url = 'https://en.wikipedia.org/wiki/Demographics_of_Toronto_neighbourhoods'
r = requests.get(url)


import pandas as pd

df = pd.read_html(r.content,attrs = {'Name', 'Population'})[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-4f82ce006515> in <module>
#       5 import pandas as pd
#       6
# ----> 7 df = pd.read_html(r.content,attrs = {'Name', 'Population'})[0]
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1092                   decimal=decimal, converters=converters, na_values=na_values,
#    1093                   keep_default_na=keep_default_na,
# -> 1094                   displayed_only=displayed_only)
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     914             break
#     915     else:
# ...
